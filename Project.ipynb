# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.metrics import silhouette_score
warnings.filterwarnings("ignore")
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from plotnine import *

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
import seaborn as sns
from sklearn.metrics import silhouette_score

# %matplotlib inline

# %%
#read the data

data_path = 'E:\Desktop\Customer Data.csv'  #the path where you downloaded the data
df = pd.read_csv(data_path)

print('The shape of the dataset is:', df.shape)
# Out:
# The shape of the dataset is: (8950, 18)

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
round(df.isnull().sum(axis=0)*100/df.shape[0],2)
# Out:
# CUST_ID                             0.00
# BALANCE                             0.00
# BALANCE_FREQUENCY                   0.00
# PURCHASES                           0.00
# ONEOFF_PURCHASES                    0.00
# INSTALLMENTS_PURCHASES              0.00
# CASH_ADVANCE                        0.00
# PURCHASES_FREQUENCY                 0.00
# ONEOFF_PURCHASES_FREQUENCY          0.00
# PURCHASES_INSTALLMENTS_FREQUENCY    0.00
# CASH_ADVANCE_FREQUENCY              0.00
# CASH_ADVANCE_TRX                    0.00
# PURCHASES_TRX                       0.00
# CREDIT_LIMIT                        0.01
# PAYMENTS                            0.00
# MINIMUM_PAYMENTS                    3.50
# PRC_FULL_PAYMENT                    0.00
# TENURE                              0.00
# dtype: float64

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df = df.fillna(df.median())

# %%
round(df.isnull().sum(axis=0)*100/df.shape[0],2)
# Out:
# CUST_ID                             0.0
# BALANCE                             0.0
# BALANCE_FREQUENCY                   0.0
# PURCHASES                           0.0
# ONEOFF_PURCHASES                    0.0
# INSTALLMENTS_PURCHASES              0.0
# CASH_ADVANCE                        0.0
# PURCHASES_FREQUENCY                 0.0
# ONEOFF_PURCHASES_FREQUENCY          0.0
# PURCHASES_INSTALLMENTS_FREQUENCY    0.0
# CASH_ADVANCE_FREQUENCY              0.0
# CASH_ADVANCE_TRX                    0.0
# PURCHASES_TRX                       0.0
# CREDIT_LIMIT                        0.0
# PAYMENTS                            0.0
# MINIMUM_PAYMENTS                    0.0
# PRC_FULL_PAYMENT                    0.0
# TENURE                              0.0
# dtype: float64

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
df["CUST_ID"] = le.fit_transform(df["CUST_ID"])
df
# Out:
#       CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0           0    40.900749           0.818182      95.40              0.00
# 1           1  3202.467416           0.909091       0.00              0.00
# 2           2  2495.148862           1.000000     773.17            773.17
# 3           3  1666.670542           0.636364    1499.00           1499.00
# 4           4   817.714335           1.000000      16.00             16.00
# ...       ...          ...                ...        ...               ...
# 8945     8945    28.493517           1.000000     291.12              0.00
# 8946     8946    19.183215           1.000000     300.00              0.00
# 8947     8947    23.398673           0.833333     144.40              0.00
# 8948     8948    13.457564           0.833333       0.00              0.00
# 8949     8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Create a scaling object
scaler = StandardScaler()

# Create a list of the variables that you need to scale
varlist = df.columns
# Scale these variables using 'fit_transform'
df[varlist] = scaler.fit_transform(df[varlist])
df
# Out:
#        CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -1.731857 -0.731989          -0.249434  -0.424900         -0.356934
# 1    -1.731470  0.786961           0.134325  -0.469552         -0.356934
# 2    -1.731083  0.447135           0.518084  -0.107668          0.108889
# 3    -1.730696  0.049099          -1.016953   0.232058          0.546189
# 4    -1.730309 -0.358775           0.518084  -0.462063         -0.347294
# ...        ...       ...                ...        ...               ...
# 8945  1.730309 -0.737950           0.518084  -0.333293         -0.356934
# 8946  1.730696 -0.742423           0.518084  -0.329136         -0.356934
# 8947  1.731083 -0.740398          -0.185477  -0.401965         -0.356934
# 8948  1.731470 -0.745174          -0.185477  -0.469552         -0.356934
# 8949  1.731857 -0.572575          -0.889033   0.042146          0.301732
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
from sklearn.decomposition import PCA

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_23666898_bb2b_11ec_b4c7_84a938fee059row0_col0,#T_23666898_bb2b_11ec_b4c7_84a938fee059row1_col1,#T_23666898_bb2b_11ec_b4c7_84a938fee059row2_col2,#T_23666898_bb2b_11ec_b4c7_84a938fee059row3_col3,#T_23666898_bb2b_11ec_b4c7_84a938fee059row4_col4,#T_23666898_bb2b_11ec_b4c7_84a938fee059row5_col5,#T_23666898_bb2b_11ec_b4c7_84a938fee059row6_col6,#T_23666898_bb2b_11ec_b4c7_84a938fee059row7_col7,#T_23666898_bb2b_11ec_b4c7_84a938fee059row8_col8,#T_23666898_bb2b_11ec_b4c7_84a938fee059row9_col9,#T_23666898_bb2b_11ec_b4c7_84a938fee059row10_col10,#T_23666898_bb2b_11ec_b4c7_84a938fee059row11_col11,#T_23666898_bb2b_11ec_b4c7_84a938fee059row12_col12,#T_23666898_bb2b_11ec_b4c7_84a938fee059row13_col13,#T_23666898_bb2b_11ec_b4c7_84a938fee059row14_col14,#T_23666898_bb2b_11ec_b4c7_84a938fee059row15_col15,#T_23666898_bb2b_11ec_b4c7_84a938fee059row16_col16,#T_23666898_bb2b_11ec_b4c7_84a938fee059row17_col17{
#             background-color:  #b40426;
# ...

# %%
#the cumulative explained variance ratio as a function of the number of components
pca = PCA().fit(df)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
pca = PCA(n_components=18)
pca.fit(df)
X_pca = pca.transform(df)
print("original shape:   ", df.shape)
print("transformed shape:", X_pca.shape)
# Out:
# original shape:    (8950, 18)
# transformed shape: (8950, 18)

# %%
print(pca.components_)
print(pca.explained_variance_)
# Out:
# [[-1.09359754e-01  1.14774047e-01  1.24081667e-01  4.09178035e-01
#    3.45528967e-01  3.32597221e-01 -1.15908955e-02  3.12217177e-01
#    2.93929335e-01  2.65091964e-01 -7.80812521e-02 -3.87239754e-02
#    3.86516024e-01  2.22976759e-01  2.71555314e-01  6.76296699e-02
#    1.24374735e-01  8.51851227e-02]
#  [-1.23665058e-01  3.99625656e-01  1.26068889e-01  2.08892726e-02
#    4.63279056e-02 -3.57810943e-02  4.33541363e-01 -2.05701337e-01
#   -2.77276764e-02 -1.93332822e-01  4.29738386e-01  4.12974386e-01
#   -3.82024619e-02  2.36251071e-01  2.42251358e-01  1.64932804e-01
#   -1.96078318e-01  5.14351889e-04]
#  [-1.56622841e-01 -1.25102124e-01 -3.91893112e-01  2.33072843e-01
#    3.71776788e-01 -1.31854581e-01 -6.61989989e-02 -3.85403072e-01
#    1.26421672e-01 -4.91973087e-01 -1.54259829e-01 -1.67863197e-01
#   -9.06423262e-02  1.44089603e-01  2.39581721e-01 -2.00445103e-01
#    8.08056837e-02  1.77479233e-02]
#  [ 4.48731154e-01 -2.48903805e-01 -2.19110524e-01  9.83483218e-02
# ...

# %%
pca = PCA(n_components=12)
pca.fit(df)
X_pca = pca.transform(df)
print("original shape:   ", df.shape)
print("transformed shape:", X_pca.shape)
# Out:
# original shape:    (8950, 18)
# transformed shape: (8950, 12)

# %%
df.head()
# Out:
#     CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -1.731857 -0.731989          -0.249434  -0.424900         -0.356934
# 1 -1.731470  0.786961           0.134325  -0.469552         -0.356934
# 2 -1.731083  0.447135           0.518084  -0.107668          0.108889
# 3 -1.730696  0.049099          -1.016953   0.232058          0.546189
# 4 -1.730309 -0.358775           0.518084  -0.462063         -0.347294
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.349079     -0.466786            -0.806490
# 1               -0.454576      2.605605            -1.221758
# 2               -0.454576     -0.466786             1.269843
# 3               -0.454576     -0.368653            -1.014125
# 4               -0.454576     -0.466786            -1.014125
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.678661                         -0.707313
# ...

# %%
X_pca = pd.DataFrame(X_pca)
X_pca.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.511585 -0.772600  0.868651 -1.320208 -0.214126  0.212059 -0.119302
# 1 -0.860031  2.758602  0.849388 -0.624452 -0.676470  1.540197  0.261019
# 2  1.159944 -0.175912  0.621790 -2.100707 -1.959350 -1.059875  1.210613
# 3 -0.680277  0.278427  1.926998 -1.475861 -0.154484  0.483968  0.548081
# 4 -1.414493 -0.386092  0.790220 -1.630078 -0.420204 -0.231319 -0.140625
#
#          7         8         9         10        11
# 0 -0.821696  1.037292  1.012434 -0.327393 -0.166891
# 1  0.056244  0.805825 -0.082478 -0.883730 -0.832515
# 2  0.319334 -0.797192  0.565600 -0.083835 -0.732075
# 3 -0.796280  0.140266  0.431197  0.269629  0.786897
# 4 -0.517588  1.348385  0.639762 -0.343063 -0.392649

# %%
corr = X_pca.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_2828d9db_bb2b_11ec_ae19_84a938fee059row0_col0,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row1_col1,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row2_col2,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row3_col3,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row4_col4,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row5_col5,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row6_col6,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row7_col7,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row8_col8,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row9_col9,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row10_col10,#T_2828d9db_bb2b_11ec_ae19_84a938fee059row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
# ...

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Counters Dendograms")
dend = shc.dendrogram(shc.linkage(y=X_pca , method="complete", metric='euclidean'),orientation='top') #fill y with your dataframe
                                                                                      #and method with linkage criteria
                                                                                      #and metric with distance function
plt.show()

# %%
#training
from sklearn.cluster import AgglomerativeClustering
clustering = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward').fit(X_pca)
clustering.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
silhouette_score(X_pca, clustering.labels_)
# Out:
# 0.3883585932361274

# %%
def kmeans(X, n_clusters):
#     ss = StandardScaler()
#     X = ss.fit_transform(X)
    km = KMeans(n_clusters=n_clusters)
    km.fit(X)
    y_pred = km.fit_predict(X)
    centroids = km.cluster_centers_
#     sns.scatterplot(X[:,0], X[:,1], hue=y_pred)
#     sns.scatterplot(centroids[:,0], centroids[:,1], s=100 , color='y')
#     plt.title("K-means")
#     plt.show()
#     print(km.labels_)
    print(silhouette_score(X, km.labels_))

#distortion function
def WCSS(x):
    wcss=[]
    for i in range(1,20):
        kmeans = KMeans(i)
        kmeans.fit(x)
        wcss_iter = kmeans.inertia_
        wcss.append(wcss_iter)
    number_clusters = range(1,20)
    plt.plot(number_clusters,wcss)
    plt.title('The Elbow title')
    plt.xlabel('Number of clusters')
    plt.ylabel('WCSS')

# %%
def hier(X, n_clusters):
#     ss = StandardScaler()
#     X = ss.fit_transform(X)
    hier = AgglomerativeClustering(n_clusters=n_clusters)
    y_pred = hier.fit_predict(X)
#     plt.scatter(X[:,0], X[:,1],c=y_pred, cmap='Paired')
#     plt.title("Hierarchical")
#     plt.show()
#     print(hier.labels_)
    print(silhouette_score(X, hier.labels_))

# %%
def dbscan(X, eps, min_samples):
#     ss = StandardScaler()
#     X = ss.fit_transform(X)
    db = DBSCAN(eps=eps, min_samples=min_samples)
    db.fit(X)
    y_pred = db.fit_predict(X)
#     plt.scatter(X[:,0], X[:,1],c=y_pred, cmap='Paired')
#     plt.title("DBSCAN")
#     plt.show()
#     print(db.labels_)
    print(silhouette_score(X, db.labels_))

# %%
def gaussianmixture(X, n_components):
#     ss = StandardScaler()
#     X = ss.fit_transform(X)
    #covariance_type: This hyperparameter controls the degrees of freedom in the shape of each cluster
    #covariance_type="diag", covariance_type='full' , covariance_type="spherical"
    #‘full’: each component has its own general covariance matrix.
    # ‘tied’: all components share the same general covariance matrix.
    # ‘diag’: each component has its own diagonal covariance matrix.
    # ‘spherical’: each component has its own single variance.
    GMM = GaussianMixture(n_components=n_components, covariance_type='spherical', random_state=42)
    GMM.fit(X)
    labels = GMM.fit_predict(X)
#     plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis')
#     plt.title("GaussianMixture")
#     plt.show()
#     print(labels)
    print(silhouette_score(X, labels))
    
def best(X):
    n_components = np.arange(1, 21)
    models = [GaussianMixture(n, covariance_type='full', random_state=0).fit(X) 
                  for n in n_components]
    plt.plot(n_components, [m.bic(X) for m in models], label='BIC')
    plt.plot(n_components, [m.aic(X) for m in models], label='AIC')
    plt.legend(loc='best')
    plt.xlabel('n_components')

# %%
dbscan(X_pca, 1.2, 6)
# Out:
# 0.110404720221111

# %%
WCSS(X_pca)

# %%
kmeans(X_pca, 2)
# Out:
# 0.20100195818196454

# %%
hier(X_pca, 2)
# Out:
# 0.3883585932361274

# %%
gaussianmixture(X_pca, 2)
# Out:
# 0.34095320947761915

# %%
best(X_pca)
